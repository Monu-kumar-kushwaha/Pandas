# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# GroupBy

# %%
data = {
    'Category': ['A','B','A','B','A','B','A','B'],
    'Store':['s1','s1','s2','s2','s1','s2','s2','s1'],
    'Sales':[100, 200, 150, 250, 120, 180, 200, 308],
    'Quality':[10, 15, 12, 18, 8, 20, 15, 25],
    'Data': pd.date_range('2023-01-01' , periods = 8)
}
df = pd.DataFrame(data)

# %%
df
# Out:
#   Category Store  Sales  Quality       Data
# 0        A    s1    100       10 2023-01-01
# 1        B    s1    200       15 2023-01-02
# 2        A    s2    150       12 2023-01-03
# 3        B    s2    250       18 2023-01-04
# 4        A    s1    120        8 2023-01-05
# 5        B    s2    180       20 2023-01-06
# 6        A    s2    200       15 2023-01-07
# 7        B    s1    308       25 2023-01-08

# %%
# Group by category and calculate the sum of sales

# %%
cat = df.groupby('Category')
cat
for i , v in cat:
    print(i)
    print(v)
# Out:
# A
#   Category Store  Sales  Quality       Data
# 0        A    s1    100       10 2023-01-01
# 2        A    s2    150       12 2023-01-03
# 4        A    s1    120        8 2023-01-05
# 6        A    s2    200       15 2023-01-07
# B
#   Category Store  Sales  Quality       Data
# 1        B    s1    200       15 2023-01-02
# 3        B    s2    250       18 2023-01-04
# 5        B    s2    180       20 2023-01-06
# 7        B    s1    308       25 2023-01-08

# %%
cat = df.groupby('Category')['Sales'].sum()
cat
# Out:
# Category
# A    570
# B    938
# Name: Sales, dtype: int64

# %%
# Group by store and calculate the sum of sales

# %%
cat = df.groupby('Store')['Sales'].sum()
cat
# Out:
# Store
# s1    728
# s2    780
# Name: Sales, dtype: int64

# %%
# Group by multiple column
# Group by Category and Store

# %%
cat = df.groupby(['Category', 'Store'])['Sales'].sum()
cat
# Out:
# Category  Store
# A         s1       220
#           s2       350
# B         s1       508
#           s2       430
# Name: Sales, dtype: int64

# %% [markdown]
# Aggregation

# %%
df['Sales'].mean()
""" mean , median, mode, max, min, std"""
# Out:
# np.float64(188.5)

# %%
df['Sales'].median()
# Out:
# 190.0

# %%
df['Sales'].mode()
# Out:
# 0    200
# Name: Sales, dtype: int64

# %%
df['Sales'].max()
# Out:
# 308

# %%
df['Sales'].min()
# Out:
# 100

# %%
df['Sales'].std()
# Out:
# 68.03990425793214

# %%
# How work multiple Aggregation

# %%
df['Sales'].agg(['sum', 'mean', 'median', 'count', 'std', 'max', 'min'])
# Out:
# sum       1508.000000
# mean       188.500000
# median     190.000000
# count        8.000000
# std         68.039904
# max        308.000000
# min        100.000000
# Name: Sales, dtype: float64
