# %%
import numpy as np
import pandas as pd

# %%
--- Creating a Data Frame ---

# %%
data = {
    'Name': ['Akash', 'Aryan', 'Ashu', 'Gaurav', 'Rahul'],
    'Age': [21, 20, 19, 23, 25],
    'city': ['Ranchi', 'Ramgarh', 'Hazariibag', 'Kolkata', 'Vikash'],
    'Salary': [67000, 70000, 44000, 80000, 70000]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#      Name  Age        city  Salary
# 0   Akash   21      Ranchi   67000
# 1   Aryan   20     Ramgarh   70000
# 2    Ashu   19  Hazariibag   44000
# 3  Gaurav   23     Kolkata   80000
# 4   Rahul   25      Vikash   70000

# %%
data_list = [
    ['Akash', 19, 'Hazaribag', 67000],
    ['Aryan', 20, 'Ramgarh', 65000],
    ['Ashu', 21, 'Ramgarh', 56000],
    ['Rahul', 23, 'vikash', 70000]
]

df2 = pd.DataFrame(data_list)
columns = ['Name', 'Age', 'City', 'Salary']
df2 = pd.DataFrame(data_list, columns = columns)

# %%
df2
# Out:
#     Name  Age       City  Salary
# 0  Akash   19  Hazaribag   67000
# 1  Aryan   20    Ramgarh   65000
# 2   Ashu   21    Ramgarh   56000
# 3  Rahul   23     vikash   70000

# %%
--- Selection and indexing of columns ---

# %%
df2
# Out:
#     Name  Age       City  Salary
# 0  Akash   19  Hazaribag   67000
# 1  Aryan   20    Ramgarh   65000
# 2   Ashu   21    Ramgarh   56000
# 3  Rahul   23     vikash   70000

# %%
df2[['Name', 'City']]
# Out:
#     Name       City
# 0  Akash  Hazaribag
# 1  Aryan    Ramgarh
# 2   Ashu    Ramgarh
# 3  Rahul     vikash

# %%
--- Creating a new Column ---

# %%
df2['Designation'] = ['BA', 'BA', 'BCOM', 'ENGINEER']

# %%
df2
# Out:
#     Name  Age       City  Salary Designation
# 0  Akash   19  Hazaribag   67000          BA
# 1  Aryan   20    Ramgarh   65000          BA
# 2   Ashu   21    Ramgarh   56000        BCOM
# 3  Rahul   23     vikash   70000    ENGINEER

# %%
--- Removing Columns ---

# %%
df2.drop('Designation', axis = 1)
# Out:
#     Name  Age       City  Salary
# 0  Akash   19  Hazaribag   67000
# 1  Aryan   20    Ramgarh   65000
# 2   Ashu   21    Ramgarh   56000
# 3  Rahul   23     vikash   70000

# %%
df2
# Out:
#     Name  Age       City  Salary Designation
# 0  Akash   19  Hazaribag   67000          BA
# 1  Aryan   20    Ramgarh   65000          BA
# 2   Ashu   21    Ramgarh   56000        BCOM
# 3  Rahul   23     vikash   70000    ENGINEER

# %%
df2.drop('Designation', axis = 1 , inplace = True)

# %%
df2
# Out:
#     Name  Age       City  Salary
# 0  Akash   19  Hazaribag   67000
# 1  Aryan   20    Ramgarh   65000
# 2   Ashu   21    Ramgarh   56000
# 3  Rahul   23     vikash   70000

# %%
df2.drop(['City', 'Salary'], axis = 1)
# Out:
#     Name  Age
# 0  Akash   19
# 1  Aryan   20
# 2   Ashu   21
# 3  Rahul   23

# %%
df2
# Out:
#     Name  Age       City  Salary
# 0  Akash   19  Hazaribag   67000
# 1  Aryan   20    Ramgarh   65000
# 2   Ashu   21    Ramgarh   56000
# 3  Rahul   23     vikash   70000

# %%
df2.drop(0, axis = 0)
# Out:
#     Name  Age     City  Salary
# 1  Aryan   20  Ramgarh   65000
# 2   Ashu   21  Ramgarh   56000
# 3  Rahul   23   vikash   70000

# %%
--- Selecting Rows ---

# %%
df2
# Out:
#     Name  Age       City  Salary
# 0  Akash   19  Hazaribag   67000
# 1  Aryan   20    Ramgarh   65000
# 2   Ashu   21    Ramgarh   56000
# 3  Rahul   23     vikash   70000

# %%
df2.loc[[0,1]]
# Out:
#     Name  Age       City  Salary
# 0  Akash   19  Hazaribag   67000
# 1  Aryan   20    Ramgarh   65000

# %%
df2.iloc[3]
# Out:
# Name       Rahul
# Age           23
# City      vikash
# Salary     70000
# Name: 3, dtype: object

# %%
--- Selecting subset of rows and columns ---

# %%
df2.loc[[0,1]] [['City', 'Salary']]
# Out:
#         City  Salary
# 0  Hazaribag   67000
# 1    Ramgarh   65000

# %%
df2.loc[[2,3]] [['Name', 'Age']]
# Out:
#     Name  Age
# 2   Ashu   21
# 3  Rahul   23

# %%
--- Conditional selection ---

# %%
df2
# Out:
#     Name  Age       City  Salary
# 0  Akash   19  Hazaribag   67000
# 1  Aryan   20    Ramgarh   65000
# 2   Ashu   21    Ramgarh   56000
# 3  Rahul   23     vikash   70000

# %%
# I only want to see these people whose age above 30

# %%
df2[df2['Age'] > 20]
# Out:
#     Name  Age     City  Salary
# 2   Ashu   21  Ramgarh   56000
# 3  Rahul   23   vikash   70000

# %%
# I only want people whose age is above 30 and their city must be Ramgarh

# %%
df2[(df2['Age'] > 20) & (df2['City'] == 'Ramgarh')]
# Out:
#    Name  Age     City  Salary
# 2  Ashu   21  Ramgarh   56000
